# %% [markdown]
# What we need
#
# 1.  Course Name
# 2.  Description
# 3.  Course Attributes
# 4.  Instructor + Course Times
# 5.  Credits

# %% [markdown]
# Scraping pipeline
#
# 1) Go to undergraduate ( https://courses.umb.edu/course_catalog/listing/ugrd )and graduate pages ( https://courses.umb.edu/course_catalog/listing/grd )
# 2) Go through each subject using it's hyperlink
# 3) Once you are in the subject page get all the courses and their associated offerings (ex: fall, spring, winter, TBA)
# 4) Find the course sections+information for each offering

# %% [markdown]
#  # Imports + Installations

# %%
import requests
from bs4 import BeautifulSoup
import time
from scraper import ( 
                     scrape_all_majors, 
                     scrape_course_sections,
                     scrape_course_offerings, 
                     HEADERS, 
                     UNDERGRADUATE_URL,
                     GRADUATE_URL
                     )
# Out:
# /Users/mckenshelcameau/mckenshels-projects/umb-app/myenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Stage 1 Find All Majors and Links to Courses

# %%
undergrad_majors = scrape_all_majors(UNDERGRADUATE_URL)
#graduate_majors = scrape_all_majors(GRADUATE_URL)

# %%
graduate_majors
# Out:
# [{'name': 'Applied Behavioral Analysis for Special Population',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_ABA_all'},
#  {'name': 'Education and Administration',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_ADM G_all'},
#  {'name': 'American Studies',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_AMST_all'},
#  {'name': 'Anthropology',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_ANTH_all'},
#  {'name': 'Applied Linguistics',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_APLING_all'},
#  {'name': 'Biology',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_BIOL_all'},
#  {'name': 'Business Administration',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_BUSADM_all'},
#  {'name': 'Advancing and Professional Studies',
#   'url': 'https://courses.umb.edu/course_catalog/courses/grd_CAPS_all'},
#  {'name': 'Provost - Program Fee',
# ...

# %% [markdown]
# # Stage 2: Find All Courses For Each Major

# %% [markdown]
# 1) Request html page for each major and find all the courses they offer
# 2) Create a dict for each major that includes their courses, when they are offered, and links to each offering

# %%
undergrad_course_offerings = scrape_course_offerings(undergrad_majors[:2])

# %%
#graduate_course_offerings = scrape_course_offerings(graduate_majors[:1])

# %%
graduate_course_offerings

# %% [markdown]
# # Stage 3 Find Info About Courses and Structure for Database

# %%
grad_sections =scrape_course_sections(graduate_course_offerings)

# %%
undergrad_sections =scrape_course_sections(undergrad_course_offerings)

# %%
undergrad_sections[56]
# Out:
# {'major': 'Africana Studies',
#  'course': 'AFRSTY 250 The Civil Rights Movement',
#  'season': '2026 Fall',
#  'link': 'https://courses.umb.edu/course_catalog/course_info/ugrd_AFRSTY_2026 Fall_250',
#  'course_info': {'description': 'This course examines the American Civil Rights movement as it developed during the period from 1954 to 1965, and as it changed during the period from 1966 to 1986. The course assesses the roles played by individuals, movements, governments, and political leaders in the process of social change.',
#   'sections': [{'Section': '01',
#     'Class Number': '1245',
#     'Schedule/Time': 'MW 5:30 - 6:45 pm',
#     'Instructor': 'Kamara,Jemadari',
#     'Location': 'Wheatley-Peters W02-0201',
#     'Session': 'Regular',
#     'Class Dates': '09/08/2026 - 12/11/2026',
#     'Credits': '3/3',
# ...

# %%
# !python3 scraper.py --max-majors 1 --level ugrd
# Out:
# /Users/mckenshelcameau/mckenshels-projects/umb-app/myenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2026-09-07 16:47:24,566 INFO __main__: Major: Accounting and Finance, URL: https://courses.umb.edu/course_catalog/courses/ugrd_AF_all
# 2026-09-07 16:47:24,785 INFO __main__: Major: Accounting and Finance
# 2026-09-07 16:48:20,199 INFO __main__: Saved 38 records for Accounting and Finance
