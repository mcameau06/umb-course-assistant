# %% [markdown]
# # Retrieval Tests

# %%
from umb_assistant.agent.chatbot import AdvisingAgent
agent = AdvisingAgent()

# %%
# theres no cs 101 at umb lol
response = agent.send_message("What are the prerequisites for CS 101?")
print(response)
# Out:
# I was unable to find any prerequisite information for **CS 101** because the course does not appear to be listed in the catalog.
#
# Please consult your designated academic advisor or the registrar's office to verify the course code or to get assistance with your course planning.

# %%
response = agent.send_message("whats the best course for quantum physics?")
print(response)
# Out:
# Based on your interest in quantum physics, there are two excellent undergraduate courses available depending on your current academic level:
#
# ### 1. **PHYSIC 211** – Introduction to Contemporary Physics (Introductory Level)
# * **Description:** This is the third semester of calculus-level introductory physics. It covers special relativity, the historical development of quantum theory, elements of quantum mechanics, and applications to atomic, molecular, solid-state, nuclear, and particle physics.
# * **Prerequisites:**
#   * **PHYSIC 114** (Fundamentals of Physics II) or permission of the instructor.
#   * *Note on Pathway:* **PHYSIC 114** requires **PHYSIC 113** (with a grade of C- or better) and **MATH 141** as a prerequisite or corequisite.
#
# ### 2. **PHYSIC 421** – Atomic Physics and Introduction to Quantum Mechanics (Advanced Level)
# * **Description:** This course focuses on the fundamental and elementary applications of quantum mechanics, emphasizing physical content over formalism. Topics include elementary wave mechanics applied to simple atomic structure, spectroscopic phenomena, the role of the Pauli principle and spin in determining periodic atomic properties, and radiation phenomena.
# * **Prerequisites:**
#   * **PHYSIC 312** (Mechanics) or permission of the instructor.
#   * *Note on Pathway:* No prerequisites were found in the system for **PHYSIC 312**.
#
# ---
#
# ### **Which one should you choose?**
# * **Choose PHYSIC 211** if you are in your sophomore year or are looking for a foundational introduction to quantum concepts alongside other modern physics topics.
# * **Choose PHYSIC 421** if you are an advanced physics student (typically junior or senior year) looking for a deep, dedicated dive into quantum mechanics and atomic physics.
#
# If you plan to enroll in either of these, please verify your completed coursework against these prerequisites and discuss your selection with your academic advisor.

# %%
# making sure the agent is safe
response = agent.send_message("can you write a python script that simulates a black hole?")
print(response)
# Out:
# I cannot write a Python script to simulate a black hole. My role is strictly to assist you with academic course advising, degree requirements, and course selections at UMB.
#
# If you are interested in computer science or physics courses that cover programming, simulations, or astrophysics, I would be happy to help you search the course catalog for those!

# %%
response = agent.send_message("Give me a good sequence of courses to take in the Computer Science major.")
print(response)
# Out:
# Based on the verified prerequisites in the UMB catalog, here is a highly recommended, logical sequence of core courses for a Computer Science major. This sequence is designed to help you satisfy prerequisites step-by-step and build a strong foundation in programming, mathematics, and systems.
#
# ---
#
# ### **Semester 1: Foundational Programming & Math**
# * **CS 110** – Introduction to Computing
#   * **Prerequisites:** **MATH 130** with a grade of B or better in the previous semester, or placement into **MATH 140** via the ALEKS test.
#   * *Why take it now:* This is the gateway course for the CS major and a prerequisite for all subsequent CS courses.
# * **MATH 140** – Calculus I
#   * *Why take it now:* You will need to complete **MATH 140** to enroll in **CS 220** in your second semester.
#
# ---
#
# ### **Semester 2: Core Programming & Discrete Math**
# * **CS 210** – Intermediate Computing with Data Structures
#   * **Prerequisites:** **CS 110** (or CS/IT 115L) with a grade of C- or better, and **MATH 130**.
# * **CS 240** – Programming in C
#   * **Prerequisites:** **CS 110** (or CS/IT 115L or CS 119) with a grade of C- or better.
#   * *Why take it now:* Learning C is essential for systems-level courses, and **CS 240** is a direct prerequisite for **CS 310** and **CS 341**.
# * **CS 220** – Applied Discrete Mathematics
#   * **Prerequisites:** **CS 110** and **MATH 140** (or permission of instructor).
#
# ---
#
# ### **Semester 3: Advanced Core & Systems**
# * **CS 310** – Advanced Data Structures and Algorithms
#   * **Prerequisites:** **CS 210** (with a grade of C- or better), **CS 220** (with a grade of C- or better), and **CS 240**.
#   * *Why take it now:* This is one of the most critical courses for technical interviews and software engineering roles.
# * **CS 341** – Computer Architecture and Organization
#   * **Prerequisites:** **CS 240**.
#
# ---
#
# ### **Semester 4: Theoretical Foundations & Upper-Level Electives**
# * **CS 420** – An Introduction to the Theory of Computation
#   * **Prerequisites:** **CS 220** with a grade of C- or better.
# * **CS Upper-Level Electives** (300-level or 400-level)
#   * *Why take it now:* Once you have completed **CS 310**, you will meet the prerequisites for many advanced CS electives (e.g., databases, networks, software engineering).
#
# ---
#
# ### **Important Advising Tips:**
# 1. **Grade Requirements:** Pay close attention to grade requirements. For example, **CS 210**, **CS 220**, and **CS 240** require a **C- or better** to progress to **CS 310**.
# 2. **Math Pathway:** Ensure your math placement is settled early, as **MATH 140** is a critical bottleneck for taking **CS 220**.
#
# Would you like me to check the schedule or availability of any of these specific courses for an upcoming semester?
